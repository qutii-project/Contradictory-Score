# %%
from transformers import pipeline
import pandas as pd
import numpy as np
import string
import scipy
import sklearn
import spacy
import nltk
import re
import os

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer, util

# %%
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()

   # Remove symbols and punctuation (except for the case where 2 follows CO)
    text = re.sub(r'[' + re.escape(string.punctuation) + '](?<![cC][oO]2)', '', text)


    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords and lemmatize
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()

    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]

    # Join the tokens back into a single string
    preprocessed_text = ' '.join(tokens)

    return preprocessed_text

# %%
# Load the pre-trained model and tokenizer
contradiction_pipeline = pipeline("text-classification", model="roberta-large-mnli")
# Out:
# Some weights of the model checkpoint at roberta-large-mnli were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def get_contradiction_score(corpus1, corpus2):
    input_text = f"{corpus1} </s></s> {corpus2}"
    result = contradiction_pipeline(input_text)

    return result

# %%
df = pd.read_csv(r"C:\Users\RedHat\Downloads\Tiiqu\Contra.csv")
df = df.iloc[:, 2:4]

# %%
df
# Out:
#                                             Statement  \
# 0   According to Krueger and Gibbs in their 2007 b...
# 1   According to Step, Slava, and Meredith, the im...
# 2   Caporale et al. used a fractional integration ...
# 3   Rite et al. examined the consistency in estima...
# 4   Shabbat et al. conducted a time-varying analys...
# ..                                                ...
# 65  Solar panels typically last around 25 to 30 ye...
# 66  Solar panels degrade over time, producing less...
# 67  There is a concern about a potential "waste mo...
# 68  Current recycling infrastructure for solar pan...
# 69  Solar panels can still be useful even after th...
#
#                              Contradictory statement
# 0   Meadows, Raiders, and Meadows in their 2004 bo...
# 1   The Environmental Subnets curve suggests that ...
# 2   The Environmental Subnets curve suggests that ...
# 3   The Environmental Subnets curve suggests that ...
# 4   The Environmental Subnets curve suggests that ...
# ..                                                ...
# 65  Experts suggest billions of solar panels will ...
# 66  Solar panels are expected to last a long time ...
# 67  Recycling options for end-of-life solar panels...
# 68  Efforts are underway to develop and scale up s...
# 69  Recycling or refurbishing solar panels is nece...
#
# [70 rows x 2 columns]

# %%
invalid_rows = df[df['Contradictory statement '] == "There is no direct contradictory statement in the provided list."]
df_cleaned = df.drop(invalid_rows.index)
# Reset the index
df_cleaned.reset_index(drop=True, inplace=True)
df_cleaned
# Out:
#                                             Statement  \
# 0   According to Krueger and Gibbs in their 2007 b...
# 1   According to Step, Slava, and Meredith, the im...
# 2   Caporale et al. used a fractional integration ...
# 3   Rite et al. examined the consistency in estima...
# 4   Shabbat et al. conducted a time-varying analys...
# 5   The Environmental Subnets curve suggests that ...
# 6   Women are more sensitive to the effects of cli...
# 7   High disruptive potential can generally be ach...
# 8   If policies lead to a phase-out of fossil fuel...
# 9   The declining rural population in Greece has a...
# 10  The fragmentation of agricultural holdings and...
# 11  The lack of proper information about new trend...
# 12  Farmers believe the cost of Precision Agricult...
# 13  De Névé and Sachs revealed that there are usua...
# 14  Economic development has been historically tie...
# 15  Pollution taxes such as those on CO2 or NH3 ar...
# 16  LA³pen and Palacios analyse the factors contri...
# 17  Environmental taxes have been assessed for the...
# 18  Very little has been done mainly due to interv...
# 19  It is important to consider policies in the fo...
# 20  One consequence could be the occurrence of str...
# 21  It is crucial to time regulatory measures to m...
# 22  Rebound effects were observed, such as in the ...
# 23  Rebound effects, such as those seen in telewor...
# 24  Lee (2018) found that while an increase in roa...
# 25  Participants who indicated the importance of l...
# 26  The legitimacy of a measure can often be asses...
# 27  On average across seven countries, only 26% of...
# 28  The highest levels of impulse shopping were re...
# 29  Almost half (44%) of the respondents on averag...
# 30  According to the IPOs Report, only 28% of Ital...
# 31  The use of farmland for growing silk can have ...
# 32  Regenerated fibres like Lowell and Tents are c...
# 33  An increase in the carbon tax parameter value ...
# 34  National Grid works with manufacturers to deve...
# 35  The Future of Solar Energy report does not pre...
# 36  Solar panels have a 30-year life cycle, and cu...
# 37  IRENA’s projections describe a billion-dollar ...
# 38  The U.S. home installations of solar panels ha...
# 39  Making an EV is more carbon intensive and expe...
# 40  Studies show that even accounting for manufact...
# 41  Electric vehicles are better for the environme...
# 42  Research shows that an EV is typically respons...
# 43  The greenhouse gas emissions associated with a...
# 44  Pesticides enable farmers to produce safe, qua...
# 45  Without pesticides, more than half of our crop...
# 46  Pesticides pose risks to environmental and hum...
# 47  Studies on pesticide risks employ different in...
# 48  Our global food system is the primary driver o...
# 49  The improper substitution with lower toxicity ...
# 50  Pesticides applied worldwide to meet food dema...
# 51  Incinerating plastic not only exacerbates clim...
# 52  Solar panels typically last around 25 to 30 ye...
# 53  Solar panels degrade over time, producing less...
# 54  There is a concern about a potential "waste mo...
# 55  Current recycling infrastructure for solar pan...
# 56  Solar panels can still be useful even after th...
#
#                              Contradictory statement
# 0   Meadows, Raiders, and Meadows in their 2004 bo...
# 1   The Environmental Subnets curve suggests that ...
# 2   The Environmental Subnets curve suggests that ...
# 3   The Environmental Subnets curve suggests that ...
# 4   The Environmental Subnets curve suggests that ...
# 5   According to Step, Slava, and Meredith, the im...
# 6   The participation of women in parliament is cr...
# 7   Pull measures are strategies that attract indi...
# 8   It is essential to time regulatory measures or...
# 9   The fragmentation of agricultural holdings and...
# 10  The lack of proper information about new trend...
# 11  Special conditions in Greek rural areas are in...
# 12  Farmers believe a complete SFT system is neces...
# 13  Environmental taxes in underdeveloped or devel...
# 14  Initially, it was assumed that a higher invest...
# 15  The wealth of countries and the general level ...
# 16  The UN Paris Agreement requires global net-zer...
# 17  Assen et al. (2020) suggest that push measures...
# 18  The European Green Deal aims to achieve climat...
# 19  Given suggests that policy challenges in trans...
# 20  It is crucial to time regulatory measures to m...
# 21  One consequence could be the occurrence of str...
# 22  Rebound effects, such as those seen in telewor...
# 23  Rebound effects were observed, such as in the ...
# 24  Hofer et al. (2018) showed that expanding the ...
# 25  In the conjoint experiment, participants rated...
# 26  Existing transport models are not usually desi...
# 27  The pandemic resulted in varied responses from...
# 28  The strongest increase in impulse shopping dur...
# 29  Among those who answered this question, 55% sa...
# 30  Yes, second-hand clothes are often inexpensive...
# 31  The socioeconomic and environmental aspects of...
# 32  Synthetic fibres like nylon and polyester star...
# 33  When the carbon tax parameter value decreases ...
# 34  National Grid removes components supplied by N...
# 35  Industry research data predicts that home inst...
# 36  Real data and scenarios suggest that rational ...
# 37  The sheer volume of discarded panels from earl...
# 38  Economic incentives are aligning to encourage ...
# 39  Even accounting for the increased emissions fr...
# 40  The emissions associated with driving an elect...
# 41  The amount of carbon pollution generated by th...
# 42  Generating the electricity used to charge EVs ...
# 43  Some studies have shown that making a typical ...
# 44  Pesticides pose risks to environmental and hum...
# 45  Studies on pesticide risks employ different in...
# 46  Pesticides help farmers grow more food on less...
# 47  Without the use of pesticides, more than half ...
# 48  Pesticides help farmers grow more food on less...
# 49  Pesticides enable farmers to produce safe, qua...
# 50  Pesticides are important. They help farmers gr...
# 51  UK households throw away an estimated 1.7 bill...
# 52  Experts suggest billions of solar panels will ...
# 53  Solar panels are expected to last a long time ...
# 54  Recycling options for end-of-life solar panels...
# 55  Efforts are underway to develop and scale up s...
# 56  Recycling or refurbishing solar panels is nece...

# %%
df_cleaned['corpus1_prepped'] = df_cleaned['Statement'].astype(str).apply(preprocess_text)
df_cleaned['corpus2_prepped'] = df_cleaned['Contradictory statement '].astype(str).apply(preprocess_text)

# %%
# Apply the function to the DataFrame
df_cleaned['Contradictory Score 1'] = df_cleaned.apply(lambda row: get_contradiction_score(row['Statement'], 
                                                                                    row['Contradictory statement ']), axis=1)

# %%
# Apply the function to the DataFrame
df_cleaned['Contradictory Score (prep)'] = df_cleaned.apply(lambda row: get_contradiction_score(row['corpus1_prepped'], 
                                                                                    row['corpus2_prepped']), axis=1)

# %%
df_cleaned
# Out:
#                                             Statement  \
# 0   According to Krueger and Gibbs in their 2007 b...
# 1   According to Step, Slava, and Meredith, the im...
# 2   Caporale et al. used a fractional integration ...
# 3   Rite et al. examined the consistency in estima...
# 4   Shabbat et al. conducted a time-varying analys...
# 5   The Environmental Subnets curve suggests that ...
# 6   Women are more sensitive to the effects of cli...
# 7   High disruptive potential can generally be ach...
# 8   If policies lead to a phase-out of fossil fuel...
# 9   The declining rural population in Greece has a...
# 10  The fragmentation of agricultural holdings and...
# 11  The lack of proper information about new trend...
# 12  Farmers believe the cost of Precision Agricult...
# 13  De Névé and Sachs revealed that there are usua...
# 14  Economic development has been historically tie...
# 15  Pollution taxes such as those on CO2 or NH3 ar...
# 16  LA³pen and Palacios analyse the factors contri...
# 17  Environmental taxes have been assessed for the...
# 18  Very little has been done mainly due to interv...
# 20  It is important to consider policies in the fo...
# 28  One consequence could be the occurrence of str...
# 30  It is crucial to time regulatory measures to m...
# 35  Rebound effects were observed, such as in the ...
# 36  Rebound effects, such as those seen in telewor...
# 37  Lee (2018) found that while an increase in roa...
# 38  Participants who indicated the importance of l...
# 39  The legitimacy of a measure can often be asses...
# 40  On average across seven countries, only 26% of...
# 41  The highest levels of impulse shopping were re...
# 42  Almost half (44%) of the respondents on averag...
# 43  According to the IPOs Report, only 28% of Ital...
# 44  The use of farmland for growing silk can have ...
# 45  Regenerated fibres like Lowell and Tents are c...
# 46  An increase in the carbon tax parameter value ...
# 47  National Grid works with manufacturers to deve...
# 48  The Future of Solar Energy report does not pre...
# 49  Solar panels have a 30-year life cycle, and cu...
# 50  IRENA’s projections describe a billion-dollar ...
# 51  The U.S. home installations of solar panels ha...
# 52  Making an EV is more carbon intensive and expe...
# 53  Studies show that even accounting for manufact...
# 54  Electric vehicles are better for the environme...
# 55  Research shows that an EV is typically respons...
# 56  The greenhouse gas emissions associated with a...
# 57  Pesticides enable farmers to produce safe, qua...
# 58  Without pesticides, more than half of our crop...
# 59  Pesticides pose risks to environmental and hum...
# 60  Studies on pesticide risks employ different in...
# 61  Our global food system is the primary driver o...
# 62  The improper substitution with lower toxicity ...
# 63  Pesticides applied worldwide to meet food dema...
# 64  Incinerating plastic not only exacerbates clim...
# 65  Solar panels typically last around 25 to 30 ye...
# 66  Solar panels degrade over time, producing less...
# 67  There is a concern about a potential "waste mo...
# 68  Current recycling infrastructure for solar pan...
# 69  Solar panels can still be useful even after th...
#
#                              Contradictory statement   \
# 0   Meadows, Raiders, and Meadows in their 2004 bo...
# 1   The Environmental Subnets curve suggests that ...
# 2   The Environmental Subnets curve suggests that ...
# 3   The Environmental Subnets curve suggests that ...
# 4   The Environmental Subnets curve suggests that ...
# 5   According to Step, Slava, and Meredith, the im...
# 6   The participation of women in parliament is cr...
# 7   Pull measures are strategies that attract indi...
# 8   It is essential to time regulatory measures or...
# 9   The fragmentation of agricultural holdings and...
# 10  The lack of proper information about new trend...
# 11  Special conditions in Greek rural areas are in...
# 12  Farmers believe a complete SFT system is neces...
# 13  Environmental taxes in underdeveloped or devel...
# 14  Initially, it was assumed that a higher invest...
# 15  The wealth of countries and the general level ...
# 16  The UN Paris Agreement requires global net-zer...
# 17  Assen et al. (2020) suggest that push measures...
# 18  The European Green Deal aims to achieve climat...
# 20  Given suggests that policy challenges in trans...
# 28  It is crucial to time regulatory measures to m...
# 30  One consequence could be the occurrence of str...
# 35  Rebound effects, such as those seen in telewor...
# 36  Rebound effects were observed, such as in the ...
# 37  Hofer et al. (2018) showed that expanding the ...
# 38  In the conjoint experiment, participants rated...
# 39  Existing transport models are not usually desi...
# 40  The pandemic resulted in varied responses from...
# 41  The strongest increase in impulse shopping dur...
# 42  Among those who answered this question, 55% sa...
# 43  Yes, second-hand clothes are often inexpensive...
# 44  The socioeconomic and environmental aspects of...
# 45  Synthetic fibres like nylon and polyester star...
# 46  When the carbon tax parameter value decreases ...
# 47  National Grid removes components supplied by N...
# 48  Industry research data predicts that home inst...
# 49  Real data and scenarios suggest that rational ...
# 50  The sheer volume of discarded panels from earl...
# 51  Economic incentives are aligning to encourage ...
# 52  Even accounting for the increased emissions fr...
# 53  The emissions associated with driving an elect...
# 54  The amount of carbon pollution generated by th...
# 55  Generating the electricity used to charge EVs ...
# 56  Some studies have shown that making a typical ...
# 57  Pesticides pose risks to environmental and hum...
# 58  Studies on pesticide risks employ different in...
# 59  Pesticides help farmers grow more food on less...
# 60  Without the use of pesticides, more than half ...
# 61  Pesticides help farmers grow more food on less...
# 62  Pesticides enable farmers to produce safe, qua...
# 63  Pesticides are important. They help farmers gr...
# 64  UK households throw away an estimated 1.7 bill...
# 65  Experts suggest billions of solar panels will ...
# 66  Solar panels are expected to last a long time ...
# 67  Recycling options for end-of-life solar panels...
# 68  Efforts are underway to develop and scale up s...
# 69  Recycling or refurbishing solar panels is nece...
#
#                                       corpus1_prepped  \
# 0   according krueger gibbs 2007 book sustainable ...
# 1   according step slava meredith impact economic ...
# 2   caporale et al used fractional integration coi...
# 3   rite et al examined consistency estimation res...
# 4   shabbat et al conducted timevarying analysis r...
# 5   environmental subnets curve suggests environme...
# 6   woman sensitive effect climate change tend fee...
# 7   high disruptive potential generally achieved p...
# 8   policy lead phaseout fossil fuel car endoflife...
# 9   declining rural population greece significant ...
# 10  fragmentation agricultural holding ageing huma...
# 11  lack proper information new trend crop product...
# 12  farmer believe cost precision agriculture equi...
# 13  de névé sachs revealed usually synergy tradeof...
# 14  economic development historically tied natural...
# 15  pollution tax co2 nh3 consistently imposed acr...
# 16  la³pen palacios analyse factor contributing eu...
# 17  environmental tax assessed impact effectivenes...
# 18  little done mainly due intervention european c...
# 20  important consider policy form package instead...
# 28  one consequence could occurrence stranded asse...
# 30  crucial time regulatory measure minimize stran...
# 35  rebound effect observed case teleworking measu...
# 36  rebound effect seen teleworking measure highli...
# 37  lee 2018 found increase road capacity optimize...
# 38  participant indicated importance living sustai...
# 39  legitimacy measure often assessed considering ...
# 40  average across seven country 26 respondent ind...
# 41  highest level impulse shopping recorded u 70 r...
# 42  almost half 44 respondent average across six c...
# 43  according ipo report 28 italian purchased fash...
# 44  use farmland growing silk impact land use may ...
# 45  regenerated fibre like lowell tent considered ...
# 46  increase carbon tax parameter value akaâ· 08t ...
# 47  national grid work manufacturer develop sf₆ al...
# 48  future solar energy report present forecast fu...
# 49  solar panel 30year life cycle customer expecte...
# 50  irena ’ projection describe billiondollar oppo...
# 51  u home installation solar panel rebounded covi...
# 52  making ev carbon intensive expensive making co...
# 53  study show even accounting manufacturing emiss...
# 54  electric vehicle better environment every metr...
# 55  research show ev typically responsible lower l...
# 56  greenhouse gas emission associated electric ve...
# 57  pesticide enable farmer produce safe quality f...
# 58  without pesticide half crop would lost pest di...
# 59  pesticide pose risk environmental human health...
# 60  study pesticide risk employ different ingredie...
# 61  global food system primary driver biodiversity...
# 62  improper substitution lower toxicity pesticide...
# 63  pesticide applied worldwide meet food demand r...
# 64  incinerating plastic exacerbates climate chang...
# 65    solar panel typically last around 25 30 year uk
# 66  solar panel degrade time producing le electric...
# 67  concern potential waste mountain solar panel 2...
# 68  current recycling infrastructure solar panel l...
# 69   solar panel still useful even efficiency decline
#
#                                       corpus2_prepped  \
# 0   meadow raider meadow 2004 book limit growth 30...
# 1   environmental subnets curve suggests environme...
# 2   environmental subnets curve suggests environme...
# 3   environmental subnets curve suggests environme...
# 4   environmental subnets curve suggests environme...
# 5   according step slava meredith impact economic ...
# 6   participation woman parliament crucial reducin...
# 7   pull measure strategy attract individual towar...
# 8   essential time regulatory measure economic tax...
# 9   fragmentation agricultural holding ageing huma...
# 10  lack proper information new trend crop product...
# 11  special condition greek rural area influenced ...
# 12  farmer believe complete sft system necessary p...
# 13  environmental tax underdeveloped developing co...
# 14  initially assumed higher investment share gdp ...
# 15  wealth country general level tax relation gdp ...
# 16  un paris agreement requires global netzero car...
# 17  assen et al 2020 suggest push measure make und...
# 18  european green deal aim achieve climate neutra...
# 20  given suggests policy challenge transport tack...
# 28  crucial time regulatory measure minimize stran...
# 30  one consequence could occurrence stranded asse...
# 35  rebound effect seen teleworking measure highli...
# 36  rebound effect observed case teleworking measu...
# 37  hofer et al 2018 showed expanding road network...
# 38  conjoint experiment participant rated product ...
# 39  existing transport model usually designed anal...
# 40  pandemic resulted varied response consumer reg...
# 41  strongest increase impulse shopping pandemic o...
# 42  among answered question 55 said impulse shoppi...
# 43  yes secondhand clothes often inexpensive compa...
# 44  socioeconomic environmental aspect silk cocoon...
# 45  synthetic fibre like nylon polyester started g...
# 46  carbon tax parameter value decrease akaâ· 08t ...
# 47  national grid remove component supplied nari t...
# 48  industry research data predicts home installat...
# 49  real data scenario suggest rational consumer r...
# 50  sheer volume discarded panel early replacement...
# 51  economic incentive aligning encourage customer...
# 52  even accounting increased emission manufacturi...
# 53  emission associated driving electric car vary ...
# 54  amount carbon pollution generated electricity ...
# 55  generating electricity used charge ev may crea...
# 56  study shown making typical ev create carbon po...
# 57  pesticide pose risk environmental human health...
# 58  study pesticide risk employ different ingredie...
# 59  pesticide help farmer grow food le land protec...
# 60  without use pesticide half crop would lost pes...
# 61  pesticide help farmer grow food le land protec...
# 62  pesticide enable farmer produce safe quality f...
# 63  pesticide important help farmer grow food le l...
# 64  uk household throw away estimated 17 billion p...
# 65  expert suggest billion solar panel need replac...
# 66  solar panel expected last long time handle var...
# 67  recycling option endoflife solar panel expandi...
# 68  effort underway develop scale solar panel recy...
# 69  recycling refurbishing solar panel necessary d...
#
#                                 Contradictory Score 1  \
# 0   [{'label': 'CONTRADICTION', 'score': 0.8791942...
# 1   [{'label': 'NEUTRAL', 'score': 0.9692577719688...
# 2   [{'label': 'NEUTRAL', 'score': 0.7406325936317...
# 3   [{'label': 'NEUTRAL', 'score': 0.9445784091949...
# 4   [{'label': 'NEUTRAL', 'score': 0.9749519228935...
# 5   [{'label': 'NEUTRAL', 'score': 0.8662146329879...
# 6   [{'label': 'NEUTRAL', 'score': 0.9756079912185...
# 7   [{'label': 'CONTRADICTION', 'score': 0.6128178...
# 8   [{'label': 'NEUTRAL', 'score': 0.9545585513114...
# 9   [{'label': 'NEUTRAL', 'score': 0.8899252414703...
# 10  [{'label': 'NEUTRAL', 'score': 0.9908842444419...
# 11  [{'label': 'NEUTRAL', 'score': 0.9635562300682...
# 12  [{'label': 'NEUTRAL', 'score': 0.8539760112762...
# 13  [{'label': 'NEUTRAL', 'score': 0.9721850752830...
# 14  [{'label': 'NEUTRAL', 'score': 0.9964518547058...
# 15  [{'label': 'NEUTRAL', 'score': 0.9766649007797...
# 16  [{'label': 'NEUTRAL', 'score': 0.9241227507591...
# 17  [{'label': 'NEUTRAL', 'score': 0.9755522608757...
# 18  [{'label': 'NEUTRAL', 'score': 0.7253891229629...
# 20  [{'label': 'NEUTRAL', 'score': 0.9938274025917...
# 28  [{'label': 'NEUTRAL', 'score': 0.9973715543746...
# 30  [{'label': 'NEUTRAL', 'score': 0.9967635869979...
# 35  [{'label': 'ENTAILMENT', 'score': 0.6112476587...
# 36  [{'label': 'ENTAILMENT', 'score': 0.9937000274...
# 37  [{'label': 'CONTRADICTION', 'score': 0.7801323...
# 38  [{'label': 'CONTRADICTION', 'score': 0.5715309...
# 39  [{'label': 'NEUTRAL', 'score': 0.9124764800071...
# 40  [{'label': 'NEUTRAL', 'score': 0.9213565587997...
# 41  [{'label': 'NEUTRAL', 'score': 0.5330679416656...
# 42  [{'label': 'NEUTRAL', 'score': 0.8026409745216...
# 43  [{'label': 'NEUTRAL', 'score': 0.9886721372604...
# 44  [{'label': 'NEUTRAL', 'score': 0.9314335584640...
# 45  [{'label': 'NEUTRAL', 'score': 0.9761217832565...
# 46  [{'label': 'CONTRADICTION', 'score': 0.7652041...
# 47  [{'label': 'CONTRADICTION', 'score': 0.9190385...
# 48  [{'label': 'CONTRADICTION', 'score': 0.5115481...
# 49  [{'label': 'CONTRADICTION', 'score': 0.8870333...
# 50  [{'label': 'NEUTRAL', 'score': 0.8530331850051...
# 51  [{'label': 'NEUTRAL', 'score': 0.9336668252944...
# 52  [{'label': 'NEUTRAL', 'score': 0.8197287917137...
# 53  [{'label': 'NEUTRAL', 'score': 0.9427704215049...
# 54  [{'label': 'NEUTRAL', 'score': 0.9893787503242...
# 55  [{'label': 'NEUTRAL', 'score': 0.9513295292854...
# 56  [{'label': 'NEUTRAL', 'score': 0.9088896512985...
# 57  [{'label': 'CONTRADICTION', 'score': 0.7428193...
# 58  [{'label': 'NEUTRAL', 'score': 0.9725049734115...
# 59  [{'label': 'NEUTRAL', 'score': 0.7396785616874...
# 60  [{'label': 'NEUTRAL', 'score': 0.7529528141021...
# 61  [{'label': 'NEUTRAL', 'score': 0.7798659205436...
# 62  [{'label': 'NEUTRAL', 'score': 0.9348286390304...
# 63  [{'label': 'CONTRADICTION', 'score': 0.5427206...
# 64  [{'label': 'NEUTRAL', 'score': 0.9563515782356...
# 65  [{'label': 'NEUTRAL', 'score': 0.6152780055999...
# 66  [{'label': 'CONTRADICTION', 'score': 0.9824237...
# 67  [{'label': 'NEUTRAL', 'score': 0.9959831237792...
# 68  [{'label': 'NEUTRAL', 'score': 0.9971781969070...
# 69  [{'label': 'NEUTRAL', 'score': 0.6030310988426...
#
#                            Contradictory Score (prep)
# 0   [{'label': 'CONTRADICTION', 'score': 0.8664186...
# 1   [{'label': 'NEUTRAL', 'score': 0.4416784644126...
# 2   [{'label': 'CONTRADICTION', 'score': 0.4790753...
# 3   [{'label': 'CONTRADICTION', 'score': 0.4012946...
# 4   [{'label': 'CONTRADICTION', 'score': 0.4408214...
# 5   [{'label': 'ENTAILMENT', 'score': 0.4339882731...
# 6   [{'label': 'NEUTRAL', 'score': 0.7121676206588...
# 7   [{'label': 'CONTRADICTION', 'score': 0.9083954...
# 8   [{'label': 'NEUTRAL', 'score': 0.5586739778518...
# 9   [{'label': 'NEUTRAL', 'score': 0.6017358899116...
# 10  [{'label': 'NEUTRAL', 'score': 0.8961516022682...
# 11  [{'label': 'NEUTRAL', 'score': 0.4000767767429...
# 12  [{'label': 'NEUTRAL', 'score': 0.7316982150077...
# 13  [{'label': 'NEUTRAL', 'score': 0.9518211483955...
# 14  [{'label': 'CONTRADICTION', 'score': 0.7899594...
# 15  [{'label': 'NEUTRAL', 'score': 0.6165982484817...
# 16  [{'label': 'NEUTRAL', 'score': 0.5650163888931...
# 17  [{'label': 'NEUTRAL', 'score': 0.5837039351463...
# 18  [{'label': 'CONTRADICTION', 'score': 0.4779377...
# 20  [{'label': 'NEUTRAL', 'score': 0.5721750259399...
# 28  [{'label': 'NEUTRAL', 'score': 0.8733383417129...
# 30  [{'label': 'NEUTRAL', 'score': 0.9465727210044...
# 35  [{'label': 'ENTAILMENT', 'score': 0.5287794470...
# 36  [{'label': 'ENTAILMENT', 'score': 0.9787274003...
# 37  [{'label': 'NEUTRAL', 'score': 0.8834636211395...
# 38  [{'label': 'NEUTRAL', 'score': 0.4274313449859...
# 39  [{'label': 'NEUTRAL', 'score': 0.4463073015213...
# 40  [{'label': 'ENTAILMENT', 'score': 0.3654558956...
# 41  [{'label': 'CONTRADICTION', 'score': 0.9210669...
# 42  [{'label': 'NEUTRAL', 'score': 0.4787856936454...
# 43  [{'label': 'NEUTRAL', 'score': 0.9947940707206...
# 44  [{'label': 'ENTAILMENT', 'score': 0.4480294585...
# 45  [{'label': 'NEUTRAL', 'score': 0.7029334306716...
# 46  [{'label': 'CONTRADICTION', 'score': 0.9960269...
# 47  [{'label': 'CONTRADICTION', 'score': 0.9186979...
# 48  [{'label': 'CONTRADICTION', 'score': 0.7068841...
# 49  [{'label': 'CONTRADICTION', 'score': 0.7700232...
# 50  [{'label': 'NEUTRAL', 'score': 0.7949494719505...
# 51  [{'label': 'NEUTRAL', 'score': 0.7216327190399...
# 52  [{'label': 'CONTRADICTION', 'score': 0.7430834...
# 53  [{'label': 'NEUTRAL', 'score': 0.8185766935348...
# 54  [{'label': 'NEUTRAL', 'score': 0.7923407554626...
# 55  [{'label': 'NEUTRAL', 'score': 0.8048052787780...
# 56  [{'label': 'NEUTRAL', 'score': 0.7849918603897...
# 57  [{'label': 'CONTRADICTION', 'score': 0.5763373...
# 58  [{'label': 'NEUTRAL', 'score': 0.9581092000007...
# 59  [{'label': 'NEUTRAL', 'score': 0.6822716593742...
# 60  [{'label': 'NEUTRAL', 'score': 0.7366767525672...
# 61  [{'label': 'NEUTRAL', 'score': 0.6339949965476...
# 62  [{'label': 'NEUTRAL', 'score': 0.7366275191307...
# 63  [{'label': 'NEUTRAL', 'score': 0.8120546936988...
# 64  [{'label': 'NEUTRAL', 'score': 0.6253935694694...
# 65  [{'label': 'NEUTRAL', 'score': 0.5069547295570...
# 66  [{'label': 'NEUTRAL', 'score': 0.8748517632484...
# 67  [{'label': 'CONTRADICTION', 'score': 0.3993650...
# 68  [{'label': 'NEUTRAL', 'score': 0.8723682165145...
# 69  [{'label': 'NEUTRAL', 'score': 0.9596259593963...

# %%
df_cleaned.to_csv('Random QA Contra_List_scoring 7-7-24.csv')

# %%
#df_cleaned.to_csv('Dataset after removing unwanted rows 7-7-24.csv')
